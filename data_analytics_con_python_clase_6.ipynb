# %% [markdown]
# <a href="https://colab.research.google.com/github/vhcontre/data-analytics-con-python/blob/main/data_analytics_con_python_clase_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Víctor H
#
# Hola! Soy Victor, y me encanta aprender Data Analytics con Python. Aquí van algunas cosas sobre mí:
#
# **Fortalezas:**
# - Trabajo en proyectos de software
# - Me gusta aprender cosas nuevas
# - Disfruto organizar y planificar
#
# *Recuerden siempre*: la práctica hace al maestro.
#
# Documentación oficial de Python: [Python Docs](https://docs.python.org/3/)
#
#
# > “El conocimiento es poder, pero la sabiduría es aplicarlo.”

# %% [markdown]
# # ©️ Clase 6

# %% [markdown]
# ## Actividad 1: Análisis de Supervivencia (Obligatoria)
#
# **Consigna:**
#
# 1. Filtrar pasajeros sobrevivientes.
# 2. Seleccionar columnas: `'sex'`, `'age'`, `'fare'`.
# 3. Crear una nueva columna según la clase del pasajero.

# %%
import seaborn as sns
import pandas as pd

# Cargar dataset Titanic desde Seaborn
df_titanic = sns.load_dataset('titanic')

# Ver las primeras filas
print(df_titanic.head())
df_titanic.to_csv("titanic.csv", index=False)

# %%
import pandas as pd
import seaborn as sns
from google.colab import files

# 1️⃣ Subir archivo Titanic desde la PC
# print("👉 Selecciona el archivo titanic.csv desde tu PC")
# uploaded = files.upload()
# nombre_archivo = list(uploaded.keys())[0]

# 2️⃣ Cargo el dataset Titanic
# df_titanic = pd.read_csv(nombre_archivo)
df_titanic = sns.load_dataset('titanic')

print("\n✅ Dataset Titanic cargado con éxito")
print("Primeras filas del dataset original:")
print(df_titanic.head())

# 3️⃣ Filtro solo a los pasajeros que sobrevivieron
df_survivors = df_titanic[df_titanic['survived'] == 1]

print("\n✅ Cantidad de sobrevivientes:", df_survivors.shape[0])

# 4️⃣ Selecciono columnas relevantes
df_selected = df_survivors[['sex', 'age', 'fare', 'class']]

print("\n✅ Columnas seleccionadas (sex, age, fare, class):")
print(df_selected.head())

# 5️⃣ Creo nueva columna con la clase categorizada
df_selected['clase_categoria'] = df_selected['class'].map({
    'First': 'Alta',
    'Second': 'Media',
    'Third': 'Baja'
})

print("\n✅ Nueva columna 'clase_categoria' creada:")
print(df_selected.head())

# 6️⃣ Resumen final (tabla con primeros registros)
print("\n📊 Dataset final preparado (primeros 10 registros):")
print(df_selected.head(10))

# 7️⃣ Guardar dataset final
df_selected.to_excel("titanic_supervivientes.xlsx", index=False)
print("\n💾 Dataset final guardado como 'titanic_supervivientes.xlsx'")

# %% [markdown]
# ### Ejemplo de salida final (tabla con primeros registros)
#
# | sex    | age  | fare   | class  | clase\_categoria |
# | ------ | ---- | ------ | ------ | ---------------- |
# | female | 38.0 | 71.283 | First  | Alta             |
# | female | 26.0 | 7.925  | Third  | Baja             |
# | female | 35.0 | 53.100 | First  | Alta             |
# | female | 27.0 | 11.133 | Third  | Baja             |
# | male   | 54.0 | 51.862 | First  | Alta             |
# | male   | 4.0  | 16.700 | Third  | Baja             |
# | female | 58.0 | 26.550 | First  | Alta             |
# | male   | 34.0 | 13.000 | Second | Media            |
# | female | 2.0  | 21.075 | Third  | Baja             |
# | female | 31.0 | 18.000 | Third  | Baja             |

# %% [markdown]
# ## Actividad 2 Manipulación de Datos
#
# **Consigna:**
#
# 1. Obtener los nombres de las columnas.
# 2. Eliminar la columna `'deck'` (contiene nulos).
# 3. Reindexar el DataFrame.

# %%
import pandas as pd
import seaborn as sns

# Cargar dataset Titanic usando Seaborn
df = sns.load_dataset('titanic')
print("Primeras filas del dataset cargado con Seaborn:")
display(df.head())

# Obtener nombres de las columnas
columnas = df.columns.tolist()
print("\nNombres de las columnas:")
print(columnas)

# Eliminar columna 'deck'
if 'deck' in df.columns:
    df = df.drop(columns=['deck'])
    print("\nColumna 'deck' eliminada correctamente.")
else:
    print("\nLa columna 'deck' no existe en el dataset.")

# Reindexar DataFrame
df = df.reset_index(drop=True)
print("\nDataFrame reindexado. Primeras filas del DataFrame modificado:")
display(df.head())

# Resumen final en tabla
resumen_final = pd.DataFrame({
    "Número de filas": [df.shape[0]],
    "Número de columnas": [df.shape[1]],
    "Columnas restantes": [df.columns.tolist()]
})
print("\nResumen final del DataFrame:")
display(resumen_final)
# Out:
# Primeras filas del dataset cargado con Seaborn:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# Nombres de las columnas:
# ...
